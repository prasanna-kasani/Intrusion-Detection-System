# %%
import pandas as pd

# Load your dataset
data = pd.read_csv('UNSW_NB15_no_outliers.csv')

# Display basic information about the dataset
print("Dataset information:")
print(data.info())

# Check for missing values
print("\nMissing values per column:")
print(data.isnull().sum())

# Check for outliers using descriptive statistics
print("\nDescriptive statistics:")
print(data.describe())

# Visualize distributions and detect outliers using box plots
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
data.boxplot()
plt.title("Box plot of features")
plt.xticks(rotation=90)
plt.show()
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11358 entries, 0 to 11357
# Data columns (total 44 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dur                11358 non-null  float64
#  1   proto              11358 non-null  object
#  2   service            11358 non-null  object
#  3   state              11358 non-null  object
#  4   spkts              11358 non-null  int64
#  5   dpkts              11358 non-null  int64
#  6   sbytes             11358 non-null  int64
#  7   dbytes             11358 non-null  int64
#  8   rate               11358 non-null  float64
#  9   sttl               11358 non-null  int64
#  10  dttl               11358 non-null  int64
#  11  sload              11358 non-null  float64
#  12  dload              11358 non-null  float64
#  13  sloss              11358 non-null  int64
#  14  dloss              11358 non-null  int64
#  15  sinpkt             11358 non-null  float64
#  16  dinpkt             11358 non-null  float64
#  17  sjit               11358 non-null  float64
#  18  djit               11358 non-null  float64
#  19  swin               11358 non-null  int64
#  20  stcpb              11358 non-null  int64
#  21  dtcpb              11358 non-null  int64
#  22  dwin               11358 non-null  int64
#  23  tcprtt             11358 non-null  float64
#  24  synack             11358 non-null  float64
#  25  ackdat             11358 non-null  float64
#  26  smean              11358 non-null  int64
#  27  dmean              11358 non-null  int64
#  28  trans_depth        11358 non-null  int64
#  29  response_body_len  11358 non-null  int64
#  30  ct_srv_src         11358 non-null  int64
#  31  ct_state_ttl       11358 non-null  int64
#  32  ct_dst_ltm         11358 non-null  int64
#  33  ct_src_dport_ltm   11358 non-null  int64
#  34  ct_dst_sport_ltm   11358 non-null  int64
#  35  ct_dst_src_ltm     11358 non-null  int64
#  36  is_ftp_login       11358 non-null  int64
#  37  ct_ftp_cmd         11358 non-null  int64
#  38  ct_flw_http_mthd   11358 non-null  int64
#  39  ct_src_ltm         11358 non-null  int64
#  40  ct_srv_dst         11358 non-null  int64
#  41  is_sm_ips_ports    11358 non-null  int64
#  42  attack_cat         11358 non-null  object
#  43  label              11358 non-null  int64
# dtypes: float64(11), int64(29), object(4)
# memory usage: 3.8+ MB
# None
#
# Missing values per column:
# dur                  0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ct_srv_dst           0
# is_sm_ips_ports      0
# attack_cat           0
# label                0
# dtype: int64
#
# Descriptive statistics:
#                 dur         spkts         dpkts        sbytes        dbytes  \
# count  11358.000000  11358.000000  11358.000000  11358.000000  11358.000000
# mean       0.734890     10.946029      8.260169    883.846012    527.719141
# std        0.400697      3.495376      3.652925    617.827187    491.821272
# min        0.000000      1.000000      0.000000     24.000000      0.000000
# 25%        0.477015     10.000000      6.000000    556.000000    268.000000
# 50%        0.680938     10.000000      8.000000    622.000000    354.000000
# 75%        0.965712     12.000000      8.000000    978.000000    646.000000
# max        2.279264     36.000000     38.000000   4400.000000   4002.000000
#
#                rate          sttl          dttl          sload          dload  \
# count  11358.000000  11358.000000  11358.000000   11358.000000   11358.000000
# mean      81.860868    224.494805    232.020250   35065.278297   19780.961067
# std      258.262617     73.305666     63.859478  121980.652969   68245.356015
# min        0.000000      0.000000      0.000000       0.000000       0.000000
# 25%       19.141492    254.000000    252.000000    5224.072266    2833.965515
# 50%       25.566724    254.000000    252.000000    7422.556152    3916.372436
# 75%       35.438989    254.000000    252.000000   13199.765622    6436.854004
# max     4366.812275    255.000000    253.000000  978165.937500  415111.531300
#
#        ...  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# count  ...      11358.000000           11358.0    11358.000000       11358.0
# mean   ...          1.192375               1.0        2.312291           0.0
# std    ...          0.444573               0.0        1.629322           0.0
# min    ...          1.000000               1.0        1.000000           0.0
# 25%    ...          1.000000               1.0        1.000000           0.0
# 50%    ...          1.000000               1.0        2.000000           0.0
# 75%    ...          1.000000               1.0        3.000000           0.0
# max    ...          3.000000               1.0        8.000000           0.0
#
#        ct_ftp_cmd  ct_flw_http_mthd    ct_src_ltm    ct_srv_dst  \
# count     11358.0           11358.0  11358.000000  11358.000000
# mean          0.0               0.0      1.818542      3.485385
# std           0.0               0.0      1.208297      2.578538
# min           0.0               0.0      1.000000      1.000000
# 25%           0.0               0.0      1.000000      1.000000
# 50%           0.0               0.0      1.000000      3.000000
# 75%           0.0               0.0      2.000000      5.000000
# max           0.0               0.0      8.000000     16.000000
#
#        is_sm_ips_ports         label
# count          11358.0  11358.000000
# mean               0.0      0.466015
# std                0.0      0.498866
# min                0.0      0.000000
# 25%                0.0      0.000000
# 50%                0.0      0.000000
# 75%                0.0      1.000000
# max                0.0      1.000000
#
# [8 rows x 40 columns]

# %%
# Plot histograms for numeric features
import matplotlib.pyplot as plt

numeric_features = data.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(15, 10))
for i, feature in enumerate(numeric_features, 1):
    plt.subplot(5, 8, i)
    plt.hist(data[feature], bins=30, color='skyblue', edgecolor='black')
    plt.title(feature)
plt.tight_layout()
plt.show()

# %%
# Plot box plots for numeric features
plt.figure(figsize=(15, 10))
for i, feature in enumerate(numeric_features, 1):
    plt.subplot(5, 8, i)
    plt.boxplot(data[feature])
    plt.title(feature)
plt.tight_layout()
plt.show()
